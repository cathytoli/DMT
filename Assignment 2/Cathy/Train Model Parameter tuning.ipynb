# %%
import pandas as pd
import numpy as np
import sklearn
from xgboost import XGBClassifier
import xgboost
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from xgboost.sklearn import XGBClassifier
from sklearn import metrics   #Additional scklearn functions
from sklearn.model_selection import cross_validate,GridSearchCV

import pickle
from sklearn.utils import shuffle
import json
import os
from xgboost import XGBClassifier
from matplotlib import pyplot
import matplotlib.pylab as plt
# %matplotlib inline
import math

# %%
#Don't use datetime, Don't use categorical features, xgboost doesn't do those, first one hot encode
featuresToUse = ['visitor_hist_starrating', 'visitor_hist_adr_usd',
       'prop_starrating', 'prop_review_score', 'prop_brand_bool',
       'prop_location_score1', 'prop_location_score2',
       'prop_log_historical_price', 'price_usd', 'promotion_flag',
       'srch_length_of_stay', 'srch_booking_window',
       'srch_adults_count', 'srch_children_count', 'srch_room_count',
       'srch_saturday_night_bool', 'srch_query_affinity_score',
       'orig_destination_distance', 'comp1_rate', 'comp1_inv',
                 'mean_prop_starrating',
       'mean_prop_review_score', 'mean_prop_brand_bool',
       'mean_prop_location_score1', 'mean_prop_location_score2',   'mean_prop_log_historical_price','cluster__0','cluster__1','cluster__2','cluster__3','cluster__4','cluster__5','diff_distance_orig','diff_price_usd']
labelToPredict = 'booking_bool'
neededVars = ['srch_id','click_bool']
nameOfModel = "models/10mayClickingOverFitTest"

# %%
dftrain = pd.read_csv('80PercentTrainWithMeanNoShuffle.csv', delimiter=",",usecols=featuresToUse+[labelToPredict]+neededVars)
dftrain = dftrain.sample(frac=0.2)
Y = dftrain[labelToPredict]

# %%
 'min_child_weight':range(1,12,2),
 'subsample':[i/10.0 for i in range(6,10)],
 'colsample_bytree':[i/10.0 for i in range(6,10)],
 'gamma':[i/10.0 for i in range(0,5)],
 'learning_rate':[i/10.0 for i in range(0,10)]

# %%
for i in range(10,21,3):
    print(i)
# Out:
# 10
# 13
# 16
# 19

# %%
param_test1 = {
    #'gamma':range(0,10,2)#,
    'learning_rate':[0,0.2,0.4,0.6,0.8,1]
}



gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate = 0.1, n_estimators=120, max_depth=5,
min_child_weight=1, gamma=0,
objective= 'reg:logistic', nthread=-1, scale_pos_weight=sum(Y==0)/sum(Y==1), seed=12,verbosity=3), 
param_grid = param_test1, scoring='roc_auc',n_jobs=5,iid=False, cv=5,verbose = 100)

gsearch1.fit(dftrain[featuresToUse],dftrain[labelToPredict])
gsearch1.cv_results_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-49e60d36f2eb4d5f970ac2a4d70e2d0f.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-76e1aeeebf4744d2bb2d32bcff019bb2.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-e4905268c4934b718207c54d0699a012.pkl
# Memmapping (shape=(634668,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-6880913813e5488ca8daa2161f9b55a3.pkl
# Memmapping (shape=(158668,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-470c49c4a3094eea88ec9145c91b1792.pkl
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-49e60d36f2eb4d5f970ac2a4d70e2d0f.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-76e1aeeebf4744d2bb2d32bcff019bb2.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-e01e1c587a504244a589ea63421b7b8a.pkl
# Memmapping (shape=(634668,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-5e2368eaa1764d6d99c8b633e0d9a7ed.pkl
# Memmapping (shape=(158668,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-d585b5dac2c146e89f7d3cddf0573b56.pkl
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-49e60d36f2eb4d5f970ac2a4d70e2d0f.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-76e1aeeebf4744d2bb2d32bcff019bb2.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18fd9bebd2b64fd799a5a12e80ea1c1c.pkl
# Memmapping (shape=(634669,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-493f64e85a7448a28e4cb1b0206940a6.pkl
# Memmapping (shape=(158667,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008
pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-d7d80fef708845d4b80f701acbe5b438.pkl
# Memmapping (shape=(634670,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-34c02789960c482fa5047f9a41c3355d.pkl
# Memmapping (shape=(158666,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-4fc0736c34a343e79e95fc10656db307.pkl
# [Parallel(n_jobs=5)]: Done  21 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=5)]: Done  22 out of  30 | elapsed: 21.1min remaining:  7.7min
# [Parallel(n_jobs=5)]: Done  23 out of  30 | elapsed: 21.2min remaining:  6.4min
# [Parallel(n_jobs=5)]: Done  24 out of  30 | elapsed: 21.2min remaining:  5.3min
# [Parallel(n_jobs=5)]: Done  25 out of  30 | elapsed: 21.3min remaining:  4.3min
# [Parallel(n_jobs=5)]: Done  26 out of  30 | elapsed: 25.5min remaining:  3.9min
# [Parallel(n_jobs=5)]: Done  27 out of  30 | elapsed: 25.5min remaining:  2.8min
# [Parallel(n_jobs=5)]: Done  28 out of  30 | elapsed: 25.5min remaining:  1.8min
# [Parallel(n_jobs=5)]: Done  30 out of  30 | elapsed: 25.6min remaining:    0.0s
# [Parallel(n_jobs=5)]: Done  30 out of  30 | elapsed: 25.6min finished
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# {'mean_fit_time': array([250.25695424, 255.03454175, 240.02899308, 251.84458179,
#         244.53342471, 255.71158624]),
#  'std_fit_time': array([1.67412775, 0.80752357, 0.73277434, 0.3092973 , 0.31287319,
#         0.34433795]),
#  'mean_score_time': array([0.83692904, 1.153547  , 1.03934116, 1.06961379, 1.02783647,
#         1.06506133]),
#  'std_score_time': array([0.11244802, 0.08897657, 0.06492548, 0.05437571, 0.02359467,
#         0.06945926]),
#  'param_learning_rate': masked_array(data=[0, 0.2, 0.4, 0.6, 0.8, 1],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'learning_rate': 0},
#   {'learning_rate': 0.2},
#   {'learning_rate': 0.4},
#   {'learning_rate': 0.6},
#   {'learning_rate': 0.8},
#   {'learning_rate': 1}],
#  'split0_test_score': array([0.5       , 0.72458218, 0.71701122, 0.70077787, 0.69105939,
#         0.68146696]),
#  'split1_test_score': array([0.5       , 0.72031402, 0.71004876, 0.70291704, 0.68599083,
#         0.67576686]),
#  'split2_test_score': array([0.5       , 0.71277498, 0.70671572, 0.68540096, 0.67928966,
#         0.66740795]),
#  'split3_test_score': array([0.5       , 0.72300043, 0.71020684, 0.69567762, 0.68823637,
#         0.67443575]),
#  'split4_test_score': array([0.5       , 0.71766332, 0.7108135 , 0.69302556, 0.68041185,
#         0.67701254]),
#  'mean_test_score': array([0.5       , 0.71966699, 0.71095921, 0.69555981, 0.68499762,
#         0.67521801]),
#  'std_test_score': array([0.        , 0.00417622, 0.00334814, 0.00618054, 0.0045129 ,
#         0.00456465]),
#  'rank_test_score': array([6, 1, 2, 3, 4, 5], dtype=int32),
#  'split0_train_score': array([0.5       , 0.78094236, 0.81237682, 0.83012377, 0.83866963,
#         0.84018661]),
#  'split1_train_score': array([0.5       , 0.78054578, 0.80877498, 0.82711425, 0.83774732,
#         0.84708631]),
#  'split2_train_score': array([0.5       , 0.78501661, 0.81154973, 0.83217777, 0.84347038,
#         0.84852393]),
#  'split3_train_score': array([0.5       , 0.78172602, 0.81369005, 0.83256668, 0.84156762,
#         0.84847956]),
#  'split4_train_score': array([0.5       , 0.7816477 , 0.81124976, 0.8321311 , 0.84141046,
#         0.84515505]),
#  'mean_train_score': array([0.5       , 0.78197569, 0.81152827, 0.83082271, 0.84057308,
#         0.84588629]),
#  'std_train_score': array([0.        , 0.00158301, 0.00161567, 0.00204111, 0.00208292,
#         0.00310301])}

# %%
gsearch1.cv_results_
# Out:
# {'mean_fit_time': array([250.25695424, 255.03454175, 240.02899308, 251.84458179,
#         244.53342471, 255.71158624]),
#  'std_fit_time': array([1.67412775, 0.80752357, 0.73277434, 0.3092973 , 0.31287319,
#         0.34433795]),
#  'mean_score_time': array([0.83692904, 1.153547  , 1.03934116, 1.06961379, 1.02783647,
#         1.06506133]),
#  'std_score_time': array([0.11244802, 0.08897657, 0.06492548, 0.05437571, 0.02359467,
#         0.06945926]),
#  'param_learning_rate': masked_array(data=[0, 0.2, 0.4, 0.6, 0.8, 1],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'learning_rate': 0},
#   {'learning_rate': 0.2},
#   {'learning_rate': 0.4},
#   {'learning_rate': 0.6},
#   {'learning_rate': 0.8},
#   {'learning_rate': 1}],
#  'split0_test_score': array([0.5       , 0.72458218, 0.71701122, 0.70077787, 0.69105939,
#         0.68146696]),
#  'split1_test_score': array([0.5       , 0.72031402, 0.71004876, 0.70291704, 0.68599083,
#         0.67576686]),
#  'split2_test_score': array([0.5       , 0.71277498, 0.70671572, 0.68540096, 0.67928966,
#         0.66740795]),
#  'split3_test_score': array([0.5       , 0.72300043, 0.71020684, 0.69567762, 0.68823637,
#         0.67443575]),
#  'split4_test_score': array([0.5       , 0.71766332, 0.7108135 , 0.69302556, 0.68041185,
#         0.67701254]),
#  'mean_test_score': array([0.5       , 0.71966699, 0.71095921, 0.69555981, 0.68499762,
#         0.67521801]),
#  'std_test_score': array([0.        , 0.00417622, 0.00334814, 0.00618054, 0.0045129 ,
#         0.00456465]),
#  'rank_test_score': array([6, 1, 2, 3, 4, 5], dtype=int32),
#  'split0_train_score': array([0.5       , 0.78094236, 0.81237682, 0.83012377, 0.83866963,
#         0.84018661]),
#  'split1_train_score': array([0.5       , 0.78054578, 0.80877498, 0.82711425, 0.83774732,
#         0.84708631]),
#  'split2_train_score': array([0.5       , 0.78501661, 0.81154973, 0.83217777, 0.84347038,
#         0.84852393]),
#  'split3_train_score': array([0.5       , 0.78172602, 0.81369005, 0.83256668, 0.84156762,
#         0.84847956]),
#  'split4_train_score': array([0.5       , 0.7816477 , 0.81124976, 0.8321311 , 0.84141046,
#         0.84515505]),
#  'mean_train_score': array([0.5       , 0.78197569, 0.81152827, 0.83082271, 0.84057308,
#         0.84588629]),
#  'std_train_score': array([0.        , 0.00158301, 0.00161567, 0.00204111, 0.00208292,
#         0.00310301])}

# %%
file = open("cvScores_learning_rate.txt","a+")
 
file.write(str(gsearch1.cv_results_))
 
file.close()

# %%
eta needs to be as small as possible: 
https://medium.com/data-design/let-me-learn-the-learning-rate-eta-in-xgboost-d9ad6ec78363
