# %%
import pandas as pd
import numpy as np
import sklearn
from xgboost import XGBClassifier
import xgboost
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from xgboost.sklearn import XGBClassifier
from sklearn import metrics   #Additional scklearn functions
from sklearn.model_selection import cross_validate,GridSearchCV

import pickle
from sklearn.utils import shuffle
import json
import os
from xgboost import XGBClassifier
from matplotlib import pyplot
import matplotlib.pylab as plt
# %matplotlib inline
import math

# %%
#Don't use datetime, Don't use categorical features, xgboost doesn't do those, first one hot encode
featuresToUse = ['visitor_hist_starrating', 'visitor_hist_adr_usd',
       'prop_starrating', 'prop_review_score', 'prop_brand_bool',
       'prop_location_score1', 'prop_location_score2',
       'prop_log_historical_price', 'price_usd', 'promotion_flag',
       'srch_length_of_stay', 'srch_booking_window',
       'srch_adults_count', 'srch_children_count', 'srch_room_count',
       'srch_saturday_night_bool', 'srch_query_affinity_score',
       'orig_destination_distance', 'comp1_rate', 'comp1_inv',
                 'mean_prop_starrating',
       'mean_prop_review_score', 'mean_prop_brand_bool',
       'mean_prop_location_score1', 'mean_prop_location_score2',   'mean_prop_log_historical_price','cluster__0','cluster__1','cluster__2','cluster__3','cluster__4','cluster__5','diff_distance_orig','diff_price_usd']
labelToPredict = 'booking_bool'
neededVars = ['srch_id','click_bool']
nameOfModel = "models/10mayClickingOverFitTest"

# %%
dftrain = pd.read_csv('80PercentTrainWithMeanNoShuffle.csv', delimiter=",",usecols=featuresToUse+[labelToPredict]+neededVars)
dftrain = dftrain.sample(frac=0.2)
Y = dftrain[labelToPredict]

# %%
 'min_child_weight':range(1,12,2),
 'subsample':[i/10.0 for i in range(6,10)],
 'colsample_bytree':[i/10.0 for i in range(6,10)],
 'gamma':[i/10.0 for i in range(0,5)],
 'learning_rate':[i/10.0 for i in range(0,10)]

# %%
for i in range(10,21,3):
    print(i)
# Out:
# 10
# 13
# 16
# 19

# %%
param_test1 = {
    'gamma':range(0,10,2)#,
    #'eta':[0,0.2,0.4,0.6,0.8,1]
}



gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate = 0.1, n_estimators=120, max_depth=5,
min_child_weight=1, gamma=0,
objective= 'reg:logistic', nthread=-1, scale_pos_weight=sum(Y==0)/sum(Y==1), seed=12,verbosity=3), 
param_grid = param_test1, scoring='roc_auc',n_jobs=5,iid=False, cv=5,verbose = 100)

gsearch1.fit(dftrain[featuresToUse],dftrain[labelToPredict])
gsearch1.cv_results_
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-1b6e64939cdf4b8f806d6743e603f045.pkl
# Memmapping (shape=(634668,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-7f89ed3b187b401dab1c47313902078b.pkl
# Memmapping (shape=(158668,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-a67c3ab103944c62b977db5c8be5d265.pkl
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-68c74e3801ce44a596eac1c4158a6afe.pkl
# Memmapping (shape=(634668,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-4beb9a4610c7434cb4386e5cef226e97.pkl
# Memmapping (shape=(158668,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-2c7bd9dd43e641409aa5ca75d0f64260.pkl
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-e73c047abcfa4d8293376d5aa93c2b66.pkl
# Memmapping (shape=(634669,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-abe25d57a02e4fb4b143773b9512d84b.pkl
# Memmapping (shape=(158667,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-813692f861df49129409b936e12d384a.pkl
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-7d695c231d0b4d0ea9d1d5861d2c6362.pkl
# Memmapping (shape=(634669,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-12b38afd9fd045498c14e13d0efe3a40.pkl
# Memmapping (shape=(158667,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-36ae70e189a44f2a8b57b71124a5605a.pkl
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-6f10ddeb6b8c46508126d08af280623f.pkl
# Memmapping (shape=(634670,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-326ad5a2b7f1408e848b61845eb2da82.pkl
# Memmapping (shape=(158666,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008
pkl
# Memmapping (shape=(158668,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-a67c3ab103944c62b977db5c8be5d265.pkl
# [Parallel(n_jobs=5)]: Done  12 tasks      | elapsed: 12.8min
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-a9f91c9138094ca4a9345d023b62a76c.pkl
# Memmapping (shape=(634668,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-4beb9a4610c7434cb4386e5cef226e97.pkl
# Memmapping (shape=(158668,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-2c7bd9dd43e641409aa5ca75d0f64260.pkl
# [Parallel(n_jobs=5)]: Done  13 tasks      | elapsed: 12.8min
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-e4700c4f31094b6fb9056c23435ac62a.pkl
# Memmapping (shape=(634669,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-abe25d57a02e4fb4b143773b9512d84b.pkl
# Memmapping (shape=(158667,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-813692f861df49129409b936e12d384a.pkl
# [Parallel(n_jobs=5)]: Done  14 tasks      | elapsed: 12.8min
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-6324af8e40c440b0a43b9b02780f65b3.pkl
# Memmapping (shape=(634669,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-12b38afd9fd045498c14e13d0efe3a40.pkl
# Memmapping (shape=(158667,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-36ae70e189a44f2a8b57b71124a5605a.pkl
# [Parallel(n_jobs=5)]: Done  15 tasks      | elapsed: 12.8min
# Pickling array (shape=(34,), dtype=object).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-02c20c1117d2417db5ac63e6405c0cbc.pkl
# Memmapping (shape=(17, 793336), dtype=float64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-408779a960b544aaa1a64e396c37da76.pkl
# Memmapping (shape=(17, 793336), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-18cfc5994dc849f594d104d1502d565a.pkl
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(17,), dtype=int64).
# Memmapping (shape=(793336,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-495a770cc4964d5bb241aeb98a5da9c7.pkl
# Memmapping (shape=(793336,), dtype=int64) to new file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-f0392c3b568a41458eaf3953297327e1.pkl
# Memmapping (shape=(634670,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-326ad5a2b7f1408e848b61845eb2da82.pkl
# Memmapping (shape=(158666,), dtype=int64) to old file /var/folders/9b/yfbxkvlx4wg10ty_5s2bm14c0000gn/T/joblib_memmapping_folder_16016_8982961508/16016-113040271008-8cf6281ab96d4f8ba4bd131d0fa890f1.pkl
# [Parallel(n_jobs=5)]: Done  16 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=5)]: Done  17 out of  25 | elapsed: 17.0min remaining:  8.0min
# [Parallel(n_jobs=5)]: Done  18 out of  25 | elapsed: 17.0min remaining:  6.6min
# [Parallel(n_jobs=5)]: Done  19 out of  25 | elapsed: 17.0min remaining:  5.4min
# [Parallel(n_jobs=5)]: Done  20 out of  25 | elapsed: 17.0min remaining:  4.3min
# [Parallel(n_jobs=5)]: Done  21 out of  25 | elapsed: 21.1min remaining:  4.0min
# [Parallel(n_jobs=5)]: Done  22 out of  25 | elapsed: 21.1min remaining:  2.9min
# [Parallel(n_jobs=5)]: Done  23 out of  25 | elapsed: 21.2min remaining:  1.8min
# [Parallel(n_jobs=5)]: Done  25 out of  25 | elapsed: 21.2min remaining:    0.0s
# [Parallel(n_jobs=5)]: Done  25 out of  25 | elapsed: 21.2min finished
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/cathytol/anaconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# {'mean_fit_time': array([254.44187608, 243.48267508, 247.92187858, 244.11523371,
#         244.40376191]),
#  'std_fit_time': array([0.33865054, 0.90029579, 0.72946221, 0.8905473 , 0.77790155]),
#  'mean_score_time': array([1.53776784, 1.29780688, 1.31372423, 1.26888185, 1.23876867]),
#  'std_score_time': array([0.0618204 , 0.09103282, 0.04843049, 0.03167351, 0.06687367]),
#  'param_gamma': masked_array(data=[0, 2, 4, 6, 8],
#               mask=[False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'gamma': 0},
#   {'gamma': 2},
#   {'gamma': 4},
#   {'gamma': 6},
#   {'gamma': 8}],
#  'split0_test_score': array([0.72797397, 0.72812233, 0.72777794, 0.72802367, 0.72750438]),
#  'split1_test_score': array([0.72382952, 0.72370984, 0.7239151 , 0.72382677, 0.72383011]),
#  'split2_test_score': array([0.7161994 , 0.71618899, 0.71662569, 0.7166351 , 0.71659473]),
#  'split3_test_score': array([0.72517554, 0.7252324 , 0.72434015, 0.72476798, 0.72524049]),
#  'split4_test_score': array([0.72108523, 0.72149921, 0.72150724, 0.72103195, 0.72105948]),
#  'mean_test_score': array([0.72285273, 0.72295055, 0.72283322, 0.72285709, 0.72284584]),
#  'std_test_score': array([0.00399919, 0.00400888, 0.00369278, 0.00382961, 0.00375959]),
#  'rank_test_score': array([3, 1, 5, 2, 4], dtype=int32),
#  'split0_train_score': array([0.75835198, 0.75797674, 0.75820228, 0.75853448, 0.75779486]),
#  'split1_train_score': array([0.75954367, 0.75897076, 0.75873338, 0.75872779, 0.75871742]),
#  'split2_train_score': array([0.76182943, 0.76042195, 0.76142256, 0.76141572, 0.76113823]),
#  'split3_train_score': array([0.76066694, 0.76018246, 0.76064664, 0.76039407, 0.76044085]),
#  'split4_train_score': array([0.76046235, 0.76062975, 0.7606292 , 0.76025455, 0.75969064]),
#  'mean_train_score': array([0.76017087, 0.75963633, 0.75992681, 0.75986532, 0.7595564 ]),
#  'std_train_score': array([0.00116478, 0.00100991, 0.00123669, 0.00108627, 0.00119242])}

# %%
gsearch1.cv_results_
# Out:
# {'mean_fit_time': array([254.44187608, 243.48267508, 247.92187858, 244.11523371,
#         244.40376191]),
#  'std_fit_time': array([0.33865054, 0.90029579, 0.72946221, 0.8905473 , 0.77790155]),
#  'mean_score_time': array([1.53776784, 1.29780688, 1.31372423, 1.26888185, 1.23876867]),
#  'std_score_time': array([0.0618204 , 0.09103282, 0.04843049, 0.03167351, 0.06687367]),
#  'param_gamma': masked_array(data=[0, 2, 4, 6, 8],
#               mask=[False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'gamma': 0},
#   {'gamma': 2},
#   {'gamma': 4},
#   {'gamma': 6},
#   {'gamma': 8}],
#  'split0_test_score': array([0.72797397, 0.72812233, 0.72777794, 0.72802367, 0.72750438]),
#  'split1_test_score': array([0.72382952, 0.72370984, 0.7239151 , 0.72382677, 0.72383011]),
#  'split2_test_score': array([0.7161994 , 0.71618899, 0.71662569, 0.7166351 , 0.71659473]),
#  'split3_test_score': array([0.72517554, 0.7252324 , 0.72434015, 0.72476798, 0.72524049]),
#  'split4_test_score': array([0.72108523, 0.72149921, 0.72150724, 0.72103195, 0.72105948]),
#  'mean_test_score': array([0.72285273, 0.72295055, 0.72283322, 0.72285709, 0.72284584]),
#  'std_test_score': array([0.00399919, 0.00400888, 0.00369278, 0.00382961, 0.00375959]),
#  'rank_test_score': array([3, 1, 5, 2, 4], dtype=int32),
#  'split0_train_score': array([0.75835198, 0.75797674, 0.75820228, 0.75853448, 0.75779486]),
#  'split1_train_score': array([0.75954367, 0.75897076, 0.75873338, 0.75872779, 0.75871742]),
#  'split2_train_score': array([0.76182943, 0.76042195, 0.76142256, 0.76141572, 0.76113823]),
#  'split3_train_score': array([0.76066694, 0.76018246, 0.76064664, 0.76039407, 0.76044085]),
#  'split4_train_score': array([0.76046235, 0.76062975, 0.7606292 , 0.76025455, 0.75969064]),
#  'mean_train_score': array([0.76017087, 0.75963633, 0.75992681, 0.75986532, 0.7595564 ]),
#  'std_train_score': array([0.00116478, 0.00100991, 0.00123669, 0.00108627, 0.00119242])}

# %%
file = open("cvScores_gamma.txt","a+")
 
file.write(str(gsearch1.cv_results_))
 
file.close()

# %%
eta needs to be as small as possible: 
https://medium.com/data-design/let-me-learn-the-learning-rate-eta-in-xgboost-d9ad6ec78363
